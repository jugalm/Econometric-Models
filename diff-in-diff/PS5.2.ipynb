# %% [markdown]
# # Problem Set 5 (Jugal Marfatia)
#
# ## Question 2.

# %%
import statsmodels.api as sm
import pandas as pd
import numpy as np
from linearmodels import PanelOLS
from linearmodels.panel import PooledOLS

df = pd.read_excel('/Users/jugalmarfatia/Downloads/jtrain1.xlsx')

# %% [markdown]
# ## Include year 1987 and 1988 and drop null values

# %%
df = df[df['hrsemp'] >= 0]
df = df[df['year'] !=1989]

df.head()
# Out:
#    year   fcode  employ       sales   avgsal  scrap  rework  tothrs  union  \
# 0  1987  410032   100.0  47000000.0  35000.0    NaN     NaN    12.0      0
# 1  1988  410032   131.0  43000000.0  37000.0    NaN     NaN     8.0      0
# 3  1987  410440    12.0   1560000.0  10500.0    NaN     NaN    12.0      0
# 4  1988  410440    13.0   1970000.0  11000.0    NaN     NaN    12.0      0
# 6  1987  410495    20.0    750000.0  17680.0    NaN     NaN    50.0      0
#
#    grant    ...     grant_1  clscrap  cgrant  clemploy   clsales    lavgsal  \
# 0      0    ...           0      NaN       0       NaN       NaN  10.463103
# 1      0    ...           0      NaN       0  0.270027 -0.088949  10.518673
# 3      0    ...           0      NaN       0       NaN       NaN   9.259130
# 4      0    ...           0      NaN       0  0.080043  0.233347   9.305651
# 6      0    ...           0      NaN       0       NaN       NaN   9.780190
#
#    clavgsal  cgrant_1   chrsemp  clhrsemp
# 0       NaN       NaN       NaN       NaN
# 1   0.05557       0.0 -8.946565 -1.165385
# 3       NaN       NaN       NaN       NaN
# 4   0.04652       0.0  0.000000  0.000000
# 6       NaN       NaN       NaN       NaN
#
# [5 rows x 30 columns]

# %%
df['E'] = df.fcode.isin(df[df['grant'] ==1].fcode.tolist()).astype(int)
df['d_1988'] = (df['year'] == 1988).astype(int)

year = pd.Categorical(df.year)
fcode = pd.Categorical(df.fcode)

df = df.set_index(['fcode', 'year'])
df['year'] = year
df['fcode'] = fcode

# %% [markdown]
# ## 2.a.i. Literal diff in diff of the means

# %%
x = df.groupby(['year', 'E'])['hrsemp'].mean()

(x[1988, 1] - x[1987, 1]) - (x[1988, 0] - x[1987, 0])
# Out:
# /anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:1: FutureWarning: 'year' is both an index level and a column label.
# Defaulting to column, but this will raise an ambiguity error in a future version
#   """Entry point for launching an IPython kernel.
# 28.012916087399294

# %% [markdown]
# ## 2.a.ii
#
# # $hrsemp_{it} = β_0 + β_1 grant_{it} + β_{2}1 (year = 1988) + β_3 E_i + u_{it} $

# %%
exog_vars = ['grant','d_1988', 'E']
exog = sm.add_constant(df[exog_vars])

mod = PanelOLS(df.hrsemp, exog)
res = mod.fit(cov_type='clustered', cluster_entity=True)
print(res)
# Out:
#                           PanelOLS Estimation Summary
# ================================================================================
# Dep. Variable:                 hrsemp   R-squared:                        0.1501
# Estimator:                   PanelOLS   R-squared (Between):              0.0692
# No. Observations:                 256   R-squared (Within):               0.4710
# Date:                Thu, Oct 04 2018   R-squared (Overall):              0.1501
# Time:                        14:00:58   Log-likelihood                   -1140.5
# Cov. Estimator:             Clustered
#                                         F-statistic:                      14.831
# Entities:                         131   P-value                           0.0000
# Avg Obs:                       1.9542   Distribution:                   F(3,252)
# Min Obs:                       1.0000
# Max Obs:                       2.0000   F-statistic (robust):             14.637
#                                         P-value                           0.0000
# Time periods:                       2   Distribution:                   F(3,252)
# Avg Obs:                       128.00
# Min Obs:                       127.00
# Max Obs:                       129.00
#
#                              Parameter Estimates
# ==============================================================================
#             Parameter  Std. Err.     T-stat    P-value    Lower CI    Upper CI
# ------------------------------------------------------------------------------
# const          9.2967     1.6680     5.5737     0.0000      6.0118      12.582
# grant          28.013     4.6539     6.0193     0.0000      18.848      37.178
# d_1988         0.3743     1.0101     0.3706     0.7113     -1.6150      2.3637
# E             -1.7057     3.9858    -0.4279     0.6691     -9.5553      6.1440
# ==============================================================================

# %% [markdown]
# ## 2.a.ii
#
# # $hrsemp_{it} = \theta_i + β_1 grant_{it} + β_{2}1 (year = 1988) +  u_{it} $

# %%
exog_vars = ['grant', 'd_1988', 'fcode']
exog = sm.add_constant(df[exog_vars])

mod = PanelOLS(df.hrsemp,  exog)
res = mod.fit()
print(res.params[0:3])
# Out:
# const      7.272056
# grant     27.877932
# d_1988     0.509323
# Name: parameter, dtype: float64

# %% [markdown]
# ## We get approximately the same diff in diff parameter estimates from all 3 techniques because they are theoretically equivalent.

# %% [markdown]
# ## 2.b Again load data and exculde null values

# %%
df = pd.read_excel('/Users/jugalmarfatia/Downloads/jtrain1.xlsx')
df = df[df['hrsemp'] >= 0]
df['E'] = df.fcode.isin(df[df['grant'] ==1].fcode.tolist()).astype(int)

year = pd.Categorical(df.year)
fcode = pd.Categorical(df.fcode)

df = df.set_index(['fcode', 'year'])
df['year'] = year
df['fcode'] = fcode
df['year*fcode'] = pd.Categorical(df['year'].astype(str)+ '_' + df['fcode'].astype(str))

# %% [markdown]
# ## 2.b.i. Run fixed effect model with time and firm dummy variables for all 3 year
# # $hrsemp_{it} = β_0 + β_1 grant_{it} + \theta_i + \lambda_t + u_{it} $

# %%
exog_vars = ['grant', 'fcode', 'year']
exog = sm.add_constant(df[exog_vars])

mod = PanelOLS(df.hrsemp,  exog)
res = mod.fit()
print(res)
# Out:
#                           PanelOLS Estimation Summary
# ================================================================================
# Dep. Variable:                 hrsemp   R-squared:                        0.8016
# Estimator:                   PanelOLS   R-squared (Between):              1.0000
# No. Observations:                 390   R-squared (Within):               0.4908
# Date:                Thu, Oct 04 2018   R-squared (Overall):              0.8016
# Time:                        14:00:58   Log-likelihood                   -1503.7
# Cov. Estimator:            Unadjusted
#                                         F-statistic:                      7.4337
# Entities:                         135   P-value                           0.0000
# Avg Obs:                       2.8889   Distribution:                 F(137,252)
# Min Obs:                       1.0000
# Max Obs:                       3.0000   F-statistic (robust):             7.4337
#                                         P-value                           0.0000
# Time periods:                       3   Distribution:                 F(137,252)
# Avg Obs:                       130.00
# Min Obs:                       127.00
# Max Obs:                       134.00
#
#                               Parameter Estimates
# ================================================================================
#               Parameter  Std. Err.     T-stat    P-value    Lower CI    Upper CI
# --------------------------------------------------------------------------------
# const            5.0443     8.2864     0.6087     0.5432     -11.275      21.364
# grant            34.039     2.4135     14.104     0.0000      29.286      38.792
# fcode.410440     5.2315     11.616     0.4504     0.6528     -17.646      28.109
# fcode.410495     26.954     11.616     2.3203     0.0211      4.0763      49.831
# fcode.410500    -4.1018     11.616    -0.3531     0.7243     -26.979      18.776
# fcode.410509    -9.2804     16.461    -0.5638     0.5734     -41.698      23.138
# fcode.419433    -0.3838     11.644    -0.0330     0.9737     -23.316      22.548
# fcode.419434    -2.7685     11.616    -0.2383     0.8118     -25.646      20.109
# fcode.419449     16.206     11.616     1.3951     0.1642     -6.6716      39.083
# fcode.419450    -5.3745     11.616    -0.4627     0.6440     -28.252      17.503
# fcode.419459     2.8935     11.616     0.2491     0.8035     -19.984      25.771
# fcode.419461    -6.3371     11.644    -0.5442     0.5868     -29.269      16.595
# fcode.419467     87.232     11.616     7.5094     0.0000      64.354      110.11
# fcode.419472     5.6074     11.644     0.4816     0.6305     -17.325      28.540
# fcode.419473    -4.7815     11.644    -0.4106     0.6817     -27.714      18.151
# fcode.419479    -2.2972     12.999    -0.1767     0.8599     -27.898      23.303
# fcode.419482     1.8982     11.616     0.1634     0.8703     -20.979      24.776
# fcode.419483    -5.0682     11.616    -0.4363     0.6630     -27.946      17.809
# fcode.419486    -5.4482     11.644    -0.4679     0.6403     -28.380      17.484
# year.1988       -1.0635     1.8836    -0.5646     0.5728     -4.7731      2.6461
# year.1989        4.2361     1.8496     2.2902     0.0228      0.5934      7.8787
# ================================================================================

# %% [markdown]
# ## 2.b.2. Run fixed effect model with time and firm dummy variables
#
# # $hrsemp_{it} = β_0 + \theta_i + \lambda_t + u_{it} $ to predict $ \hat{u_{it}}$
# # $grant_{it} = a_0 + \theta_i + \lambda_t + e_{it} $ to predict $ \hat{e_{it}}$
#
# # *Running the above two regression is tehoretically equivalent to running seperate regression for each form with constant and time trends because we allow for different intercept for each firm.

# %%
exog_vars = ['year', 'fcode']
exog = sm.add_constant(df[exog_vars])

mod = PanelOLS(df.hrsemp,  exog)
res = mod.fit()
df['y_res'] = res.predict()

# %%
exog_vars = ['year', 'fcode']
exog = sm.add_constant(df[exog_vars])

mod = PanelOLS(df.grant,  exog)
res = mod.fit()
df['grant_res'] = res.predict()

# %% [markdown]
# # $ \hat{e_{it}} = c_0 + \hat{u_{it}} $

# %%
exog_vars = ['grant_res']
exog = sm.add_constant(df[exog_vars])

mod = PanelOLS(df.y_res,  exog)
res = mod.fit()
print(res)
# Out:
#                           PanelOLS Estimation Summary
# ================================================================================
# Dep. Variable:                  y_res   R-squared:                        0.0860
# Estimator:                   PanelOLS   R-squared (Between):              0.0511
# No. Observations:                 390   R-squared (Within):               0.7492
# Date:                Thu, Oct 04 2018   R-squared (Overall):              0.0860
# Time:                        14:00:58   Log-likelihood                   -1716.2
# Cov. Estimator:            Unadjusted
#                                         F-statistic:                      36.520
# Entities:                         135   P-value                           0.0000
# Avg Obs:                       2.8889   Distribution:                   F(1,388)
# Min Obs:                       1.0000
# Max Obs:                       3.0000   F-statistic (robust):             36.520
#                                         P-value                           0.0000
# Time periods:                       3   Distribution:                   F(1,388)
# Avg Obs:                       130.00
# Min Obs:                       127.00
# Max Obs:                       134.00
#
#                              Parameter Estimates
# ==============================================================================
#             Parameter  Std. Err.     T-stat    P-value    Lower CI    Upper CI
# ------------------------------------------------------------------------------
# const          10.351     1.2591     8.2212     0.0000      7.8759      12.827
# grant_res      30.513     5.0492     6.0432     0.0000      20.586      40.440
# ==============================================================================

# %% [markdown]
# # I get a similar estimate to the previous regression because they are theoretically equivalent.
